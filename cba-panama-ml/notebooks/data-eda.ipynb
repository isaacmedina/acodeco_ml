# %% [markdown]
# ## Exploración de Datos

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
# %matplotlib inline

# %%
# Leer y combinar todos los archivos CSV y XLS de la carpeta raw en un solo DataFrame
import os
import glob

raw_dir = '../data/raw/'
file_types = ['*.csv', '*.xls', '*.xlsx']
all_files = []
for year in os.listdir(raw_dir):
    year_path = os.path.join(raw_dir, year)
    if os.path.isdir(year_path):
        for ext in file_types:
            all_files.extend(glob.glob(os.path.join(year_path, ext)))

dfs = []
for file in all_files:
    print(f'Leyendo archivo: {file}')
    if file.endswith('.csv'):
        dfs.append(pd.read_csv(file, encoding='latin1', on_bad_lines='skip'))
    elif file.endswith('.xls') or file.endswith('.xlsx'):
        dfs.append(pd.read_excel(file))

df_all = pd.concat(dfs, ignore_index=False)
print(f'Total archivos leídos: {len(all_files)}')
print(f'Tamaño del DataFrame combinado: {df_all.shape}')
# Out:
# Leyendo archivo: ../data/raw/2020\cbacsv_nov2020.csv
# Leyendo archivo: ../data/raw/2020\cbapromsector_feb2020.csv
# Leyendo archivo: ../data/raw/2020\cba_agosto2020.csv
# Leyendo archivo: ../data/raw/2020\cba_dic2020.csv
# Leyendo archivo: ../data/raw/2020\cba_junio2020.csv
# Leyendo archivo: ../data/raw/2020\cba_mar2020.csv
# Leyendo archivo: ../data/raw/2020\cba_octubre2020.csv
# Leyendo archivo: ../data/raw/2020\cba_sept2020.csv
# Leyendo archivo: ../data/raw/2020\cba_julio2020.xls
# Leyendo archivo: ../data/raw/2021\cba_abril2021csv.csv
# Leyendo archivo: ../data/raw/2021\cba_ago2021.csv
# Leyendo archivo: ../data/raw/2021\cba_enero2021-csv.csv
# Leyendo archivo: ../data/raw/2021\cba_febrero2021-csv.csv
# Leyendo archivo: ../data/raw/2021\cba_julio2021-csv.csv
# Leyendo archivo: ../data/raw/2021\cba_marzo_csv2021.csv
# Leyendo archivo: ../data/raw/2021\cba_nov2021.csv
# Leyendo archivo: ../data/raw/2021\cba_sept2021csv.csv
# Leyendo archivo: ../data/raw/2022\cbamayo2022.csv
# Leyendo archivo: ../data/raw/2022\cba_abril2022_csv.csv
# Leyendo archivo: ../data/raw/2022\cba_ene2022.csv
# Leyendo archivo: ../data/raw/2022\cba_feb2022.csv
# Leyendo archivo: ../data/raw/2022\cba_junio2022.csv
# Leyendo archivo: ../data/raw/2022\cba_marzo2022csv.csv
# Total archivos leídos: 23
# Tamaño del DataFrame combinado: (1371, 263)

# %%
# Explorar el DataFrame con pandasgui (interfaz gráfica interactiva)
from pandasgui import show
show(df_all)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#
# C:\Users\Isaac\AppData\Local\Temp\ipykernel_1808\3044204102.py:3: FutureWarning:
#
# Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
raw_dir = '../data/raw/'
paths = ['2020/cba_agosto2020.csv', '2020/cba_dic2020.csv']
df2020_1 = pd.read_csv(raw_dir + paths[0], encoding='latin1')
df2020_1.head()
# Out:
#                               Producto Unidad de Medida  \
# 0  Babilla (Carne de res de Primera) *      1 Kilogramo
# 1                   Bistec de Cinta  *      1 Kilogramo
# 2           Carne Molida de Primera  *      1 Kilogramo
# 3          Carne para Sopa (Costilla)       1 Kilogramo
# 4                         Puerco Liso       1 Kilogramo
#
#    CASA DE LA CARNE CANGREJO  REY DE VIA ESPA¥A  RIBA SMITH BELLA VISTA  \
# 0                        NaN                NaN                     NaN
# 1                       4.96               5.62                    5.62
# 2                        NaN               3.75                    4.74
# 3                       4.70                NaN                     NaN
# 4                       7.80                NaN                   11.83
#
#    RIBA SMITH TRANSISTMICA  SUPER 99 CAMINO REAL  SUPER 99 EL DORADO  \
# 0                     6.55                   NaN                 NaN
# 1                     5.62                  5.19                5.19
# 2                     4.74                  4.74                4.74
# 3                      NaN                   NaN                 NaN
# 4                    11.83                   NaN                 NaN
#
#    SUPER 99 TUMBA MUERTO  XTRA TUMBA MUERTO  ...  MINISUPER PLAZA AMADOR  \
# 0                    NaN                NaN  ...                     NaN
# 1                    NaN                NaN  ...                     NaN
# 2                   4.74                NaN  ...                     NaN
# 3                    NaN               3.54  ...                     NaN
# 4                   4.99                NaN  ...                    6.06
#
#    ABT EDITH- SANTA ANA  MINISUPER EXPRESO-CALIDONIA  MINISUPER ROY-CALIDONIA  \
# 0                   NaN                          NaN                      NaN
# 1                  5.62                          NaN                      NaN
# 2                   NaN                          NaN                      NaN
# 3                   NaN                          NaN                      NaN
# 4                  7.17                         6.28                      NaN
#
#    MINISUPER EL MILENIO  M/S VILLA ZAITA  ABARROTERÖA BERAKA  ABT - LA PAGODA  \
# 0                   NaN              NaN                 NaN             6.33
# 1                   NaN              NaN                 NaN             5.40
# 2                   NaN              NaN                 NaN             5.51
# 3                   NaN              NaN                 NaN              NaN
# 4                   NaN              NaN                 NaN             4.96
#
#    ABT. LA PAGODA NO. 2  M/S MULTI CARNES
# 0                  6.05              6.54
# 1                  4.51              6.52
# 2                  4.73              3.75
# 3                   NaN               NaN
# 4                  5.17              5.62
#
# [5 rows x 90 columns]

# %%
df2020_1.describe().round(2)
# Out:
#        CASA DE LA CARNE CANGREJO  REY DE VIA ESPA¥A  RIBA SMITH BELLA VISTA  \
# count                      45.00              43.00                   50.00
# mean                        2.84               2.29                    3.00
# std                         2.57               1.89                    2.91
# min                         0.50               0.35                    0.45
# 25%                         1.00               0.95                    0.92
# 50%                         1.77               1.68                    2.00
# 75%                         3.76               2.92                    3.79
# max                        11.29               8.20                   14.30
#
#        RIBA SMITH TRANSISTMICA  SUPER 99 CAMINO REAL  SUPER 99 EL DORADO  \
# count                    53.00                 47.00               46.00
# mean                      3.23                  2.37                2.25
# std                       3.22                  2.13                2.03
# min                       0.45                  0.35                0.35
# 25%                       0.92                  0.94                0.96
# 50%                       2.12                  1.79                1.72
# 75%                       3.94                  2.73                2.54
# max                      14.30                 11.49               10.57
#
#        SUPER 99 TUMBA MUERTO  XTRA TUMBA MUERTO  EL MACHETAZO COSTA SUR  \
# count                  47.00              47.00                   51.00
# mean                    2.56               2.19                    2.70
# std                     2.44               2.19                    2.48
# min                     0.35               0.27                    0.41
# 25%                     0.94               0.91                    0.94
# 50%                     1.79               1.66                    2.07
# 75%                     2.72               2.62                    3.20
# max                    10.99              11.46                   10.65
#
#        EL MACHETAZO METRO MALL  ...  MINISUPER PLAZA AMADOR  \
# count                    49.00  ...                   30.00
# mean                      2.58  ...                    1.86
# std                       2.48  ...                    1.72
# min                       0.40  ...                    0.35
# 25%                       0.93  ...                    0.81
# 50%                       1.75  ...                    1.25
# 75%                       2.71  ...                    2.20
# max                      11.75  ...                    8.27
#
#        ABT EDITH- SANTA ANA  MINISUPER EXPRESO-CALIDONIA  \
# count                 26.00                        21.00
# mean                   2.14                         1.81
# std                    2.10                         1.56
# min                    0.35                         0.50
# 25%                    0.86                         0.75
# 50%                    1.40                         1.25
# 75%                    2.65                         2.31
# max                    8.71                         6.28
#
#        MINISUPER ROY-CALIDONIA  MINISUPER EL MILENIO  M/S VILLA ZAITA  \
# count                    22.00                 38.00            37.00
# mean                      1.51                  2.10             2.06
# std                       1.29                  1.65             1.58
# min                       0.30                  0.40             0.40
# 25%                       0.75                  0.86             0.85
# 50%                       1.04                  1.50             1.54
# 75%                       1.75                  2.90             3.31
# max                       5.75                  7.72             7.39
#
#        ABARROTERÖA BERAKA  ABT - LA PAGODA  ABT. LA PAGODA NO. 2  \
# count               36.00            40.00                 41.00
# mean                 1.93             2.50                  1.93
# std                  1.29             2.20                  1.61
# min                  0.45             0.30                  0.25
# 25%                  0.88             0.89                  0.75
# 50%                  1.44             1.74                  1.45
# 75%                  2.96             3.32                  2.71
# max                  5.95            10.45                  6.58
#
#        M/S MULTI CARNES
# count             40.00
# mean               2.25
# std                1.90
# min                0.30
# 25%                0.87
# 50%                1.74
# 75%                3.19
# max                8.26
#
# [8 rows x 88 columns]

# %%
with open(raw_dir + paths[1], encoding='latin1') as f:
    lines = f.readlines()[1:]  # Remueve la primera fila

from io import StringIO
df2020_2 = pd.read_csv(StringIO(''.join(lines)))
df2020_2.head()
# Out:
#                               Producto        Medida  \
# 0  Babilla (Carne de res de Primera) *  1 Kilogramos
# 1                    Bistec de Cinta *  1 Kilogramos
# 2            Carne Molida de Primera *  1 Kilogramos
# 3         Carne para Sopa (Costilla) *  1 Kilogramos
# 4                        Puerco Liso *  1 Kilogramos
#
#    CASA DE LA CARNE CANGREJO  REY DE VIA ESPA¥A  RIBA SMITH BELLA VISTA  \
# 0                        NaN               6.55                    6.55
# 1                       4.96               5.84                     NaN
# 2                        NaN                NaN                    4.74
# 3                        NaN                NaN                     NaN
# 4                       7.80               5.51                     NaN
#
#    RIBA SMITH TRANSISTMICA  REY EL DORADO  SUPER 99 CAMINO REAL  \
# 0                      NaN            NaN                   NaN
# 1                     5.62           5.84                  5.62
# 2                      NaN            NaN                  4.74
# 3                      NaN            NaN                  4.45
# 4                    14.47            NaN                   NaN
#
#    SUPER 99 EL DORADO  SUPER 99 TUMBA MUERTO  ...  ABT EDITH- SANTA ANA  \
# 0                 NaN                    NaN  ...                   NaN
# 1                5.62                   5.62  ...                  5.62
# 2                 NaN                    NaN  ...                   NaN
# 3                 NaN                    NaN  ...                   NaN
# 4                 NaN                   5.75  ...                  5.51
#
#    MINISUPER EXPRESO-CALIDONIA  MINISUPER ROY-CALIDONIA  MINISUPER EL MILENIO  \
# 0                          NaN                      NaN                   NaN
# 1                          NaN                      NaN                   NaN
# 2                          NaN                      NaN                   NaN
# 3                          NaN                      NaN                  6.06
# 4                          NaN                      NaN                  6.50
#
#    M/S VILLA ZAITA  M/S OCANO  ABARROTERÖA BERAKA  ABT - LA PAGODA  \
# 0              NaN         NaN                 NaN             6.06
# 1              NaN         NaN                 NaN              NaN
# 2              NaN        4.74                 NaN             4.74
# 3              NaN         NaN                 NaN              NaN
# 4             7.17         NaN                 NaN             6.37
#
#    ABT. LA PAGODA NO. 2  M/S MULTI CARNES
# 0                  6.33              6.54
# 1                  5.40               NaN
# 2                  4.39              4.41
# 3                   NaN               NaN
# 4                  5.40              5.62
#
# [5 rows x 92 columns]

# %%
df2020_2.describe()
# Out:
#        CASA DE LA CARNE CANGREJO  REY DE VIA ESPA¥A  RIBA SMITH BELLA VISTA  \
# count                  37.000000          40.000000               38.000000
# mean                    2.512973           2.585750                2.708421
# std                     2.119820           2.106106                2.189853
# min                     0.500000           0.490000                0.450000
# 25%                     0.900000           1.025000                0.965000
# 50%                     1.760000           1.895000                1.960000
# 75%                     3.760000           3.190000                3.895000
# max                     8.890000           8.050000                9.100000
#
#        RIBA SMITH TRANSISTMICA  REY EL DORADO  SUPER 99 CAMINO REAL  \
# count                45.000000      42.000000             47.000000
# mean                  3.088889       2.540952              2.588723
# std                   3.159382       2.498913              2.334796
# min                   0.450000       0.490000              0.350000
# 25%                   0.920000       1.025000              0.970000
# 50%                   2.050000       1.875000              1.760000
# 75%                   3.760000       3.057500              3.490000
# max                  14.470000      14.490000             11.490000
#
#        SUPER 99 EL DORADO  SUPER 99 TUMBA MUERTO  XTRA TUMBA MUERTO  \
# count           41.000000              50.000000          48.000000
# mean             2.312195               2.687400           2.339792
# std              1.836565               2.396259           2.289316
# min              0.350000               0.350000           0.340000
# 25%              0.890000               1.005000           0.867500
# 50%              1.760000               1.840000           1.675000
# 75%              2.840000               3.160000           2.747500
# max              7.690000              10.990000          11.460000
#
#        EL MACHETAZO COSTA SUR  ...  ABT EDITH- SANTA ANA  \
# count               39.000000  ...              25.00000
# mean                 2.354872  ...               2.10800
# std                  2.281725  ...               1.95167
# min                  0.390000  ...               0.25000
# 25%                  0.815000  ...               0.75000
# 50%                  1.490000  ...               1.25000
# 75%                  2.735000  ...               2.65000
# max                  8.270000  ...               8.05000
#
#        MINISUPER EXPRESO-CALIDONIA  MINISUPER ROY-CALIDONIA  \
# count                    21.000000                18.000000
# mean                      1.614762                 1.354444
# std                       1.289863                 1.038983
# min                       0.500000                 0.350000
# 25%                       0.770000                 0.750000
# 50%                       1.000000                 0.925000
# 75%                       1.650000                 1.642500
# max                       4.950000                 4.410000
#
#        MINISUPER EL MILENIO  M/S VILLA ZAITA  M/S OCANO  ABARROTERÖA BERAKA  \
# count             41.000000        36.000000   31.000000           32.000000
# mean               2.571951         2.277500    1.744194            1.746250
# std                2.056964         1.951358    1.293081            1.294192
# min                0.400000         0.450000    0.250000            0.350000
# 25%                0.880000         0.850000    0.865000            0.850000
# 50%                1.870000         1.595000    1.250000            1.250000
# 75%                3.640000         3.310000    2.350000            2.807500
# max                7.720000         8.710000    5.350000            5.950000
#
#        ABT - LA PAGODA  ABT. LA PAGODA NO. 2  M/S MULTI CARNES
# count        41.000000             37.000000         39.000000
# mean          2.331220              2.197027          2.355641
# std           1.980091              1.636279          2.092588
# min           0.250000              0.490000          0.200000
# 25%           0.850000              0.880000          0.860000
# 50%           1.960000              1.960000          1.600000
# 75%           2.870000              3.060000          3.200000
# max           7.690000              6.330000          8.260000
#
# [8 rows x 88 columns]

# %%
df = pd.concat([df2020_1, df2020_2], ignore_index=True)
df.describe().round(2)
# Out:
#        CASA DE LA CARNE CANGREJO  REY DE VIA ESPA¥A  RIBA SMITH BELLA VISTA  \
# count                      82.00              83.00                   88.00
# mean                        2.69               2.43                    2.87
# std                         2.37               1.99                    2.61
# min                         0.50               0.35                    0.45
# 25%                         0.90               0.95                    0.92
# 50%                         1.76               1.75                    1.96
# 75%                         3.76               3.02                    3.84
# max                        11.29               8.20                   14.30
#
#        RIBA SMITH TRANSISTMICA  SUPER 99 CAMINO REAL  SUPER 99 EL DORADO  \
# count                    98.00                 94.00               87.00
# mean                      3.16                  2.48                2.28
# std                       3.18                  2.22                1.93
# min                       0.45                  0.35                0.35
# 25%                       0.92                  0.95                0.94
# 50%                       2.08                  1.78                1.76
# 75%                       3.80                  2.80                2.72
# max                      14.47                 11.49               10.57
#
#        SUPER 99 TUMBA MUERTO  XTRA TUMBA MUERTO  EL MACHETAZO COSTA SUR  \
# count                  97.00              95.00                   90.00
# mean                    2.62               2.26                    2.55
# std                     2.40               2.23                    2.39
# min                     0.35               0.27                    0.39
# 25%                     0.95               0.89                    0.89
# 50%                     1.79               1.66                    1.54
# 75%                     2.89               2.70                    2.95
# max                    10.99              11.46                   10.65
#
#        EL MACHETAZO METRO MALL  ...  MINISUPER EXPRESO-CALIDONIA  \
# count                    85.00  ...                        42.00
# mean                      2.61  ...                         1.71
# std                       2.42  ...                         1.42
# min                       0.40  ...                         0.50
# 25%                       0.93  ...                         0.76
# 50%                       1.75  ...                         1.12
# 75%                       2.98  ...                         2.21
# max                      11.75  ...                         6.28
#
#        MINISUPER ROY-CALIDONIA  MINISUPER EL MILENIO  M/S VILLA ZAITA  \
# count                    40.00                 79.00            73.00
# mean                      1.44                  2.34             2.17
# std                       1.17                  1.87             1.77
# min                       0.30                  0.40             0.40
# 25%                       0.75                  0.86             0.85
# 50%                       0.97                  1.54             1.54
# 75%                       1.75                  3.31             3.31
# max                       5.75                  7.72             8.71
#
#        ABARROTERÖA BERAKA  ABT - LA PAGODA  ABT. LA PAGODA NO. 2  \
# count               68.00            81.00                 78.00
# mean                 1.85             2.41                  2.06
# std                  1.29             2.08                  1.62
# min                  0.35             0.25                  0.25
# 25%                  0.85             0.88                  0.79
# 50%                  1.34             1.96                  1.48
# 75%                  2.95             3.28                  2.87
# max                  5.95            10.45                  6.58
#
#        M/S MULTI CARNES  REY EL DORADO  M/S OCANO
# count             79.00          42.00       31.00
# mean               2.30           2.54        1.74
# std                1.98           2.50        1.29
# min                0.20           0.49        0.25
# 25%                0.86           1.02        0.86
# 50%                1.60           1.88        1.25
# 75%                3.20           3.06        2.35
# max                8.26          14.49        5.35
#
# [8 rows x 88 columns]
